# %%
import pandas as pd

# %%
facts = pd.read_csv('../data/state_facts.tsv',delimiter="\t")
facts.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ...        City_1 city_1_pop       City_2  \
# ...

# %%
#Question 1-District of Columbia, New Jersey, Rhode Island, Puerto Rico, Massachusetts

facts['Pop_density_2020']=facts['Pop_2020']/facts['Area_land']
Q1=facts.sort_values(by=['Pop_density_2020'], ascending=False)
Q1.head(5)
# Out:
#                      State  Area_tot  Area_land  Area_water   Pop_2020  \
# 9    District of Columbia        177        158          19   689545.0
# 32             New Jersey      22591      19047        3544  9288994.0
# 43           Rhode Island       4001       2678        1324  1097379.0
# 42            Puerto Rico      13791       8868        4924  3285874.0
# 23          Massachusetts      27336      20202        7134  7029917.0
#
#     Pop_2010 Rep_seats                               State_bird  \
# 9     601723       1*                              Wood thrush
# 32   8791894        12  Eastern goldfinch (American goldfinch)
# 43   1052567         2                        Rhode Island Red
# 42   3725789       1*                                     None
# 23   6547629         9                  Black-capped chickadee
#
#              State_flower                                 State_motto  ...  \
# 9   American Beauty Rose                            Justitia Omnibus   ...
# ...

# %%
#2- American Samoa, Guam, Northern Mariana Islands, United States Virgin Islands
facts[facts['Area_water']>facts['Area_land']]
# Out:
#                              State  Area_tot  Area_land  Area_water  Pop_2020  \
# 2                  American Samoa       1505        198        1307   49437.0
# 12                           Guam       1478        543         935     168.4
# 37       Northern Mariana Islands       5117        472        4644      51.0
# 48   United States Virgin Islands       1898        348        1550  106235.0
#
#     Pop_2010 Rep_seats           State_bird                State_flower  \
# 2      55519       1*                  None            Paogo (Ulafala)
# 12    159358       1*   Guam rail (ko'ko')   Bougainvillea spectabilis
# 37     53883       1*   Mariana fruit-dove                 Flores mayo
# 48    106405       1*      California gull                Yellow Elder
#
#                     State_motto  ... city_1_pop      City_2  city_2_pop  \
# 2        Samoa, Muamua Le Atua   ...       7945    Nu'uuli       3955.0
# ...

# %%
#Question 3-Texas, Florida, California, Georgia, Washington
facts['Growth']=facts['Pop_2020']-facts['Pop_2010']
Q3=facts.sort_values(by=['Growth'], ascending=False)
Q3.head(5)
# Out:
#            State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 47        Texas     695662     676587       19075  29145505.0  25145561
# 10      Florida     170312     138887       31424  21538187.0  18801310
# 5    California     423967     403466       20501  39538223.0  37253956
# 11      Georgia     153910     148959        4951  10711908.0   9687653
# 52   Washington     184661     172119       12542   7705281.0   6724540
#
#    Rep_seats                              State_bird         State_flower  \
# 47        38                   Northern mockingbird       Bluebonnet sp.
# 10        28                   Northern mockingbird        Orange blossom
# 5         52                       California quail     California poppy
# 11        14                         Brown thrasher         Cherokee rose
# 52        10  Willow goldfinch (American goldfinch)   Coast rhododendron
#
#                      State_motto  ...        City_2 city_2_pop     City_3  \
# ...

# %%
#Question 4- Northern Mockingbird

Q4=facts.groupby(by='State_bird').sum()
Q4.sort_values(by='Pop_2020', ascending=False).head(1)
# Out:
#                        Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# State_bird
# Northern mockingbird    1238297    1178574       59722  63567335.0  56176191
#
#                         GDP_2020   GDP_2019  Capital_pop  city_1_pop  \
# State_bird
# Northern mockingbird   3463383.0  3573810.6      2202168     4262215
#
#                        city_2_pop  city_3_pop  city_4_pop  city_5_pop  \
# State_bird
# Northern mockingbird    2818895.0   2087169.0   1575653.0   1454625.0
#
#                        Pop_density_2020     Growth
# State_bird
# Northern mockingbird         309.575693  7391144.0

# %%
#Question 4 (Part 2)-Willow Ptarmigan

Q4.sort_values(by='Area_land', ascending=False).head(1)
# Out:
#                    Area_tot  Area_land  Area_water  Pop_2020  Pop_2010  \
# State_bird
# Willow ptarmigan    1723337    1477953      245384  733391.0    710231
#
#                    GDP_2020  GDP_2019  Capital_pop  city_1_pop  city_2_pop  \
# State_bird
# Willow ptarmigan    50246.7   54385.6        32113      291538     32113.0
#
#                    city_3_pop  city_4_pop  city_5_pop  Pop_density_2020  \
# State_bird
# Willow ptarmigan      31516.0     10529.0      8647.0          0.496221
#
#                     Growth
# State_bird
# Willow ptarmigan   23160.0

# %%
#Question 5- Attached in chart below

facts[facts['Capital_pop']==facts['city_1_pop']]
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 3                         Arizona     295234     294207        1026
# 4                        Arkansas     137732     134771        2961
# 6                        Colorado     269601     268431        1170
# 9            District of Columbia        177        158          19
# 11                        Georgia     153910     148959        4951
# 13                         Hawaii      28313      16635       11678
# 14                          Idaho     216443     214045        2398
# 16                        Indiana      94326      92789        1537
# 17                           Iowa     145746     144669        1077
# 23                  Massachusetts      27336      20202        7134
# 26                    Mississippi     125438     121531        3907
# 37       Northern Mariana Islands       5117        472        4644
# 38                           Ohio     116098     105829       10269
# ...

# %%
#Question 6-New York

facts['range_in_city_pop']=100*(facts['city_1_pop']-facts['city_5_pop'])/(facts['city_1_pop'])
Q6=facts.sort_values(by=['range_in_city_pop'], ascending=False)

# %%
Q6.head(1)
# Out:
#          State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 34   New York     141297     122057       19240  20201249.0  19378102
#
#    Rep_seats         State_bird State_flower  State_motto  ... city_2_pop  \
# 34        26  Eastern bluebird         Rose   Excelsior!   ...   251298.0
#
#         City_3  city_3_pop    City_4 city_4_pop     City_5 city_5_pop  \
# 34  Rochester     206284.0  Yonkers    199663.0  Syracuse    142749.0
#
#     Pop_density_2020    Growth  range_in_city_pop
# 34        165.506681  823147.0          98.392453
#
# [1 rows x 29 columns]

# %%
dates=pd.read_csv('../data/state_dates.tsv',delimiter="\t")

# %%
dates['Dates_Fixed']=pd.to_datetime(dates['Date'],errors='raise')
dates[['Dates','Date_Fixed']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 dates['Dates_Fixed']=pd.to_datetime(dates['Date'],errors='raise')
# ----> 2 dates[['Dates','Date_Fixed']]
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
# ...

# %%
from datetime import datetime

# %%
dates
# Out:
#                             Name               Date            Status  \
# 0                       Alabama   December 14, 1819             State
# 1                        Alaska     January 3, 1959             State
# 2                 American Samoa     April 17, 1900         Territory
# 3                       Arizona   February 14, 1912             State
# 4                      Arkansas       June 15, 1836             State
# 5                    California   September 9, 1850             State
# 6                      Colorado      August 1, 1876             State
# 7                   Connecticut     January 9, 1788             State
# 8                      Delaware    December 7, 1787             State
# 9           District of Columbia  February 21, 1871  Federal District
# 10                      Florida       March 3, 1845             State
# 11                      Georgia     January 2, 1788             State
# ...

# %%
data=pd.merge(facts,dates,left_on='USPS_code',right_on='Abbreviation',how='outer')

# %%
#Question 7-Mountain Lauel
OG_13=data[data['Dates_Fixed']<pd.datetime(1790,1,1)]
OG_13.groupby(by='State_flower').count()
# Out:
# /tmp/ipykernel_1598269/1042289659.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   OG_13=data[data['Dates_Fixed']<pd.datetime(1790,1,1)]
#                    State  Area_tot  Area_land  Area_water  Pop_2020  Pop_2010  \
# State_flower
# American dogwood       1         1          1           1         1         1
# Black-eyed susan       1         1          1           1         1         1
# Cherokee rose          1         1          1           1         1         1
# Flowering dogwood      1         1          1           1         1         1
# Mayflower              1         1          1           1         1         1
# Mountain laurel        2         2          2           2         2         2
# Peach blossom          1         1          1           1         1         1
# Purple lilac           1         1          1           1         1         1
# ...

# %%
#Question 8-Puerto Rico's density is greater than Alaska's density
data[data['Status'].str.contains('Territory')].sort_values(by='Pop_density_2020',ascending = False)
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 42                    Puerto Rico      13791       8868        4924
# 48   United States Virgin Islands       1898        348        1550
# 2                  American Samoa       1505        198        1307
# 12                           Guam       1478        543         935
# 37       Northern Mariana Islands       5117        472        4644
#
#      Pop_2020  Pop_2010 Rep_seats           State_bird  \
# 42  3285874.0   3725789       1*                 None
# 48   106235.0    106405       1*      California gull
# 2     49437.0     55519       1*                  None
# 12      168.4    159358       1*   Guam rail (ko'ko')
# 37       51.0     53883       1*   Mariana fruit-dove
#
#                   State_flower                  State_motto  ...  \
# 42               Flor de Maga       Joannes Est Nomen Eius   ...
# 48               Yellow Elder      United in Pride and Hope  ...
# ...

# %%
#Question 8 (Part 2)
data[data['Status'].str.contains('State')].sort_values(by='Pop_density_2020', ascending = True)
# Out:
#                State  Area_tot  Area_land  Area_water    Pop_2020  Pop_2010  \
# 1            Alaska    1723337    1477953      245384    733391.0    710231
# 55          Wyoming     253335     251470        1864    576851.0    563626
# 28          Montana     380831     376962        3869   1084225.0    989415
# 36     North Dakota     183108     178711        4397    779094.0    672591
# 45     South Dakota     199729     196350        3379    886667.0    814180
# 33       New Mexico     314917     314161         757   2117522.0   2059179
# 14            Idaho     216443     214045        2398   1839106.0   1567582
# 29         Nebraska     200330     198974        1356   1961504.0   1826341
# 30           Nevada     286380     284332        2048   3104614.0   2700551
# 18           Kansas     213100     211754        1346   2937880.0   2853118
# 49             Utah     219882     212818        7064   3271616.0   2763885
# ...

# %%
#Question 9-
import matplotlib as plt
# %config InlineBackend.figure_format ='retina'

plot = data['city_1_pop'].plot(kind='bar',figsize=(10,4))
plot.set_xticklabels(data['State']);

# %%
#Question 10

plot = data['Area_land'].plot(kind='bar',color='g', figsize=(10,4))
plot.set_xticklabels(data['State']);
